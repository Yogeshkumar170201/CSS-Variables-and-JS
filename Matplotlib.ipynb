# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogeshkumar170201/CSS-Variables-and-JS/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numpy

# %%
import numpy as np

# %%
np.random.random()
# Out:
# 0.21073367979248214

# %%
np.random.randint(10, 20, 20)
# Out:
# array([19, 18, 18, 10, 15, 18, 17, 12, 18, 19, 10, 18, 15, 11, 18, 14, 13,
#        12, 12, 14])

# %%
 np.random.randint(10, 20, 20).reshape(4, 5)
# Out:
# array([[13, 13, 17, 18, 10],
#        [16, 14, 11, 13, 15],
#        [14, 18, 14, 16, 12],
#        [15, 10, 16, 15, 14]])

# %%
 np.random.randint(10, 20, size=(4, 5))
# Out:
# array([[16, 11, 11, 15, 10],
#        [18, 16, 19, 19, 17],
#        [12, 10, 11, 18, 12],
#        [10, 16, 19, 12, 18]])

# %%
data = np.random.randn(1000)

# %%
data
# Out:
# array([ 4.97566520e-01, -9.75425800e-01, -7.90838983e-01, -3.66528676e-01,
#        -2.61184318e-02,  5.41576226e-01, -5.62137364e-01, -1.97964862e+00,
#        -1.11575861e+00, -1.15030691e+00,  7.98898974e-01,  7.89248371e-02,
#        -7.44849285e-01,  1.92849466e+00,  4.71260939e-01, -8.39041555e-01,
#         1.06359951e+00,  2.23849753e-01,  1.51924270e+00,  3.62957744e-01,
#        -9.70604922e-01,  3.55129856e-01,  3.36291653e-01,  2.19749101e-01,
#         4.42627780e-01,  3.35221143e-01,  2.63457977e+00,  6.05523143e-01,
#         2.38582117e+00, -1.61441367e+00, -6.63153272e-02,  5.41684746e-01,
#         4.47118778e-01, -1.47443217e+00,  1.48921038e+00,  2.69119454e-01,
#         1.35268784e+00,  4.31995634e-01, -1.00399853e+00,  7.68152113e-01,
#         5.10567829e-02,  5.01286534e-01,  8.93984762e-01,  4.14859887e-01,
#        -1.43906647e+00, -7.67480230e-01,  1.08319648e+00,  1.86239804e-01,
# ...

# %%
data.mean()
# Out:
# 0.007769276278166736

# %%
data.std()
# Out:
# 1.0026911124547224

# %% [markdown]
# N-D Numpy

# %%
a = np.random.randint(0, 10, size=(4, 5, 2))

# %%
a.size
# Out:
# 40

# %%
a.mean()
# Out:
# 3.8

# %%
a.shape
# Out:
# (4, 5, 2)

# %%
b =  np.random.randint(0, 10, size=(5, 6))

# %%
b
# Out:
# array([[3, 0, 0, 4, 2, 3],
#        [5, 1, 6, 7, 7, 1],
#        [2, 2, 6, 3, 1, 6],
#        [5, 7, 7, 7, 3, 6],
#        [5, 3, 5, 6, 1, 2]])

# %%
b.sum()
# Out:
# 116

# %%
b.sum(axis=1)
# Out:
# array([12, 27, 20, 35, 22])

# %%
b.sum(axis=0)
# Out:
# array([20, 13, 24, 27, 14, 18])

# %% [markdown]
# b.sum?

# %%
b.sum(axis=0, keepdims=True)
# Out:
# array([[20, 13, 24, 27, 14, 18]])

# %%
b.sum(axis=0).shape
# Out:
# (6,)

# %%
b.sum(axis=0, keepdims=True).shape
# Out:
# (1, 6)

# %% [markdown]
# np.linspace

# %%
np.linspace?

# %%
np.linspace(0, 10, 15)
# Out:
# array([ 0.        ,  0.71428571,  1.42857143,  2.14285714,  2.85714286,
#         3.57142857,  4.28571429,  5.        ,  5.71428571,  6.42857143,
#         7.14285714,  7.85714286,  8.57142857,  9.28571429, 10.        ])

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x = np.linspace(0, 2*np.pi, 100)

# %% [markdown]
# sin takes an array as input

# %%
y = np.sin(x)

# %% [markdown]
# Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x, y)

# %%
x = [9, 10, 13, 17]

# %%
y = [10, 5, 20, 30]

# %%
plt.plot(x, y)

# %% [markdown]
# Circle

# %%
r = 10

# %%
theta = np.linspace(0, 2*np.pi, 200)

# %%
x = r*np.cos(theta)

# %%
y = r*np.sin(theta)

# %%
plt.plot(x, y)

# %%
plt.figure(figsize=(4,4))
plt.plot(x, y)

# %%
plt.figure(figsize=(1, 1))
plt.plot(x, y)

# %%
x = np.linspace(2, 20, 10)

# %%
m, c = 3, 10

# %%
y = m*x+c

# %%
plt.plot(x, y)

# %%
plt.plot(y, x)

# %%
plt.scatter(x, y)

# %%
x = np.linspace(2, 20, 1000)

# %%
m, c = 3, 10

# %%
y = m*x+c

# %%
plt.plot(x, y)

# %% [markdown]
# Scatter

# %%
plt.scatter(x, y)

# %%
noise = np.random.randn(1000)

# %%
noise = np.random.randn(1000)*5

# %%
y_mod = y + noise

# %%
plt.scatter(x, y_mod)

# %%
x = np.linspace(-10, 10, 40)

# %%
y = x * x

# %%
plt.plot(y, x)

# %% [markdown]
# Histogram

# %%
x = np.random.randn(10000)

# %%
out = plt.hist(x, bins=120)

# %%
out = plt.hist(x, bins=5)

# %%
x = np.random.randint(-4, 4, 1000)

# %%
out = plt.hist(x, bins=120)

# %% [markdown]
# Pie Chart

# %%
plt.pie([10, 20, 30])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f995fccc810>,
# ...
#  [Text(0.9526279355804298, 0.5500000148652441, ''),
#   Text(-0.5500000594609755, 0.9526279098330699, ''),
#   Text(1.0298943251329445e-07, -1.0999999999999954, '')])

# %%
out = plt.pie([10, 20, 30])

# %%
out = plt.pie([10, 20, 30], explode = [0, .1, 0])

# %%
out = plt.pie([10, 20, 30], explode = [0, .1, 0], shadow = True)

# %%
out = plt.pie([10, 20, 30], explode = [0, .1, 0], shadow = True, radius=1)

# %% [markdown]
# Seaborn

# %%
import seaborn as sns

# %%
sns.displot?

# %%
x = np.random.randn(1000)

# %%
sns.displot(x, bins=30)

# %%
sns.displot(x, bins=30, kde = True)

# %% [markdown]
# gaussian Kernel Density Estimate (KDE)

# %%
sns.displot(x, bins=30, kde = True, rug = True)

# %%
sns.distplot(x, bins=30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(x, bins=30, rug=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
data  = sns.load_dataset("iris")

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data = sns.load_dataset("tips")

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.head?

# %%
data.head(n = 8)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4

# %%
sns.scatterplot?

# %%
sns.scatterplot(data["total_bill"], data["tip"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Hue - Color

# %%
sns.scatterplot(data["total_bill"], data["tip"], hue=data["smoker"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
 type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data["total_bill"]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
sns.violinplot(x = data.total_bill)

# %%
sns.violinplot(y = data.total_bill)

# %%
 from sklearn.datasets import load_boston

# %%
X, y = load_boston(return_X_y = True)

# %%
sns.violinplot(y=y)

# %% [markdown]
# Outlier - Kept and removed
# Kept - Fraud Transaction
# Removed - Usian Bolt Speed

# %%
sns.violinplot(x=X)

# %%
sns.displot?

# %%
sns.boxplot(y = y)
